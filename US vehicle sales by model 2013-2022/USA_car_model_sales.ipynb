# %%
import bar_chart_race as bcr

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/jsu/Downloads/cars/us_car_model_sales_2013_2022_wide.csv', index_col='Year')

# %%
df
# Out:
#            Acura ILX  Acura Integra  Acura TL  Acura TLX  Acura TSX  Acura RL  \
# Year
# Year 2013      20430              0     24318          0      17484         0
# Year 2014      17854              0     10616      19127       6287         0
# Year 2015      18531              0        88      47080         35         0
# Year 2016      14597              0         0      37156          4         0
# Year 2017      11757              0         0      34846          0         0
# Year 2018      11273              0         0      30468          0         0
# Year 2019      14685              0         0      26548          0         0
# Year 2020      13414              0         0      21785          0         0
# Year 2021      13900              0         0      26100          0         0
# Year 2022       6296          13027         0      11508          0         0
#
#            Acura RLX  Acura RLX/RL  Acura NSX  Acura RDX  ...  VW Jetta  \
# ...

# %%
# Aggregate the date
df.iloc[:, 0:-1] = df.iloc[:, 0:-1].cumsum()

# %%
bcr.bar_chart_race(df = df, 
                   n_bars = 20, 
                   sort='desc',
                   title='US_vehicles_sales_2013_2022',
                   filename = 'US_vehicles_sales_2013_2022.mp4')
# Out:
# C:\Users\jsu\Anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 127 () missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# C:\Users\jsu\Anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# C:\Users\jsu\Anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# C:\Users\jsu\Anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 130 (\x82) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# C:\Users\jsu\Anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 131 (\x83) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# ...
